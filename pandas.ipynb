# %%
import numpy as np
import pandas as pd

# %%
labels = ['a','b','c']

my_list = [10,20,30]

arr = np.array(my_list)
d = {'a':10,'b':20,'c':30}

# %%
pd.Series(my_list, labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr, labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
sales_data = pd.Series(data=[250,450,234,234,567], index=['USA','Chine','Senegal','Bresil','Inde'])

# %%
sales_data
# Out:
# USA        250
# Chine      450
# Senegal    234
# Bresil     234
# Inde       567
# dtype: int64

# %%
sales_data1 = pd.Series(data=[250,450,300,274,567], index=['USA','Chine','Senegal','Bresil','Japan'])

# %%
sales_data1
# Out:
# USA        250
# Chine      450
# Senegal    300
# Bresil     274
# Japan      567
# dtype: int64

# %%
sales_data1['USA']
# Out:
# 250

# %%
sales_data1[0]
# Out:
# 250

# %%
sales_data1 + sales_data
# Out:
# Bresil     508.0
# Chine      900.0
# Inde         NaN
# Japan        NaN
# Senegal    534.0
# USA        500.0
# dtype: float64

# %% [markdown]
# Dataframes

# %%
col = ['W','X','Y','Z']

# %%
index = ['A','B','C','D', 'E']

# %%
np.random.seed(42)
data = np.random.randint(-100, 100,(5,4))

# %%
data
# Out:
# array([[  2,  79,  -8, -86],
#        [  6, -29,  88, -80],
#        [  2,  21, -26, -13],
#        [ 16,  -1,   3,  51],
#        [ 30,  49, -48, -99]])

# %%
df = pd.DataFrame(data, index, col)

# %%
df
# Out:
#     W   X   Y   Z
# A   2  79  -8 -86
# B   6 -29  88 -80
# C   2  21 -26 -13
# D  16  -1   3  51
# E  30  49 -48 -99

# %%
df['W']
# Out:
# A     2
# B     6
# C     2
# D    16
# E    30
# Name: W, dtype: int64

# %%
df[['W','Z']]
# Out:
#     W   Z
# A   2 -86
# B   6 -80
# C   2 -13
# D  16  51
# E  30 -99

# %%
df['new'] = df['W'] + df['Y']

# %%
df
# Out:
#     W   X   Y   Z  new
# A   2  79  -8 -86   -6
# B   6 -29  88 -80   94
# C   2  21 -26 -13  -24
# D  16  -1   3  51   19
# E  30  49 -48 -99  -18

# %%
df.drop('new', axis=1)
# Out:
#     W   X   Y   Z
# A   2  79  -8 -86
# B   6 -29  88 -80
# C   2  21 -26 -13
# D  16  -1   3  51
# E  30  49 -48 -99

# %%
df = df.drop('new', axis=1)

# %%
df
# Out:
#     W   X   Y   Z
# A   2  79  -8 -86
# B   6 -29  88 -80
# C   2  21 -26 -13
# D  16  -1   3  51
# E  30  49 -48 -99

# %%
df.loc['A']
# Out:
# W     2
# X    79
# Y    -8
# Z   -86
# Name: A, dtype: int64

# %%
df.loc[['A','C']]
# Out:
#    W   X   Y   Z
# A  2  79  -8 -86
# C  2  21 -26 -13

# %%
df.iloc[3]
# Out:
# W    16
# X    -1
# Y     3
# Z    51
# Name: D, dtype: int64

# %%
df.iloc[[1,3]]
# Out:
#     W   X   Y   Z
# B   6 -29  88 -80
# D  16  -1   3  51

# %%
df.drop('C')
# Out:
#     W   X   Y   Z
# A   2  79  -8 -86
# B   6 -29  88 -80
# D  16  -1   3  51
# E  30  49 -48 -99

# %%
df.loc['C', 'W']
# Out:
# 2

# %%
df.loc[['A','B'],['W','Y']]
# Out:
#    W   Y
# A  2  -8
# B  6  88

# %%
df > 0
# Out:
#       W      X      Y      Z
# A  True   True  False  False
# B  True  False   True  False
# C  True   True  False  False
# D  True  False   True   True
# E  True   True  False  False

# %%
df[df>0]
# Out:
#     W     X     Y     Z
# A   2  79.0   NaN   NaN
# B   6   NaN  88.0   NaN
# C   2  21.0   NaN   NaN
# D  16   NaN   3.0  51.0
# E  30  49.0   NaN   NaN

# %%
df[df['X']>0]
# Out:
#     W   X   Y   Z
# A   2  79  -8 -86
# C   2  21 -26 -13
# E  30  49 -48 -99

# %%
df[(df['W']>0) & (df['Y'] > 1)]
# Out:
#     W   X   Y   Z
# B   6 -29  88 -80
# D  16  -1   3  51

# %%
df.reset_index()
# Out:
#   index   W   X   Y   Z
# 0     A   2  79  -8 -86
# 1     B   6 -29  88 -80
# 2     C   2  21 -26 -13
# 3     D  16  -1   3  51
# 4     E  30  49 -48 -99

# %%
new_index = 'CA NY WY OR CO'.split()

# %%
new_index
# Out:
# ['CA', 'NY', 'WY', 'OR', 'CO']

# %%
df['States'] = new_index

# %%
df
# Out:
#     W   X   Y   Z States
# A   2  79  -8 -86     CA
# B   6 -29  88 -80     NY
# C   2  21 -26 -13     WY
# D  16  -1   3  51     OR
# E  30  49 -48 -99     CO

# %%
df = df.set_index('States')

# %%
df
# Out:
#          W   X   Y   Z
# States
# CA       2  79  -8 -86
# NY       6 -29  88 -80
# WY       2  21 -26 -13
# OR      16  -1   3  51
# CO      30  49 -48 -99

# %%
df.columns
# Out:
# Index(['W', 'X', 'Y', 'Z'], dtype='object')

# %%
df.describe()
# Out:
#               W          X          Y          Z
# count   5.00000   5.000000   5.000000   5.000000
# mean   11.20000  23.800000   1.800000 -45.400000
# std    11.96662  42.109381  51.915316  63.366395
# min     2.00000 -29.000000 -48.000000 -99.000000
# 25%     2.00000  -1.000000 -26.000000 -86.000000
# 50%     6.00000  21.000000  -8.000000 -80.000000
# 75%    16.00000  49.000000   3.000000 -13.000000
# max    30.00000  79.000000  88.000000  51.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, CA to CO
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       5 non-null      int64
#  1   X       5 non-null      int64
#  2   Y       5 non-null      int64
#  3   Z       5 non-null      int64
# dtypes: int64(4)
# memory usage: 372.0+ bytes

# %%
df.dtypes
# Out:
# W    int64
# X    int64
# Y    int64
# Z    int64
# dtype: object

# %%
df = pd.DataFrame({'A':[1,2,np.nan, 4],
                   'B':[5,np.nan,np.nan, 3],
                   'C':[6,7,1,4]})

# %%
df.fillna(value=df.mean())
# Out:
#           A    B  C
# 0  1.000000  5.0  6
# 1  2.000000  4.0  7
# 2  2.333333  4.0  1
# 3  4.000000  3.0  4

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  6
# 1  2.0  NaN  7
# 2  NaN  3.0  1
# 3  4.0  3.0  4

# %%
df.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  6
# 3  4.0  3.0  4

# %%
df.dropna(axis=1, thresh=4)
# Out:
#    C
# 0  6
# 1  7
# 2  1
# 3  4

# %%
df.fillna(value=0)
# Out:
#           A    B  C
# 0  1.000000  5.0  6
# 1  2.000000  4.0  7
# 2  2.333333  4.0  1
# 3  4.000000  3.0  4

# %%
df['A'] = df['A'].fillna(value=df['A'].mean())

# %%
df['B'] = df['B'].fillna(value=df['B'].mean())

# %%
df
# Out:
#           A    B  C
# 0  1.000000  5.0  6
# 1  2.000000  4.0  7
# 2  2.333333  4.0  1
# 3  4.000000  3.0  4

# %% [markdown]
# Opérations avec groupby

# %%
df = pd.read_csv('Universities.csv')

# %%
df.head() # Affichage des 5 premières lignes
# Out:
#                                  Sector  \
# 0            Private for-profit, 2-year
# 1  Private for-profit, less-than 2-year
# 2  Private for-profit, less-than 2-year
# 3  Private for-profit, less-than 2-year
# 4               Public, 4-year or above
#
#                               University  Year  Completions Geography
# 0       Pima Medical Institute-Las Vegas  2016          591    Nevada
# 1       Healthcare Preparatory Institute  2016           28    Nevada
# 2              Milan Institute-Las Vegas  2016          408    Nevada
# 3  Utah College of Massage Therapy-Vegas  2016          240    Nevada
# 4                 Western Nevada College  2016          960    Nevada

# %%
df.groupby('Year').mean('completions')
# Out:
#       Completions
# Year
# 2012   535.078947
# 2013   526.150000
# 2014   588.809524
# 2015   597.250000
# 2016   609.860465

# %%
df.groupby(['Year','Sector']).sum('completions')
# Out:
#                                               Completions
# Year Sector
# 2012 Private for-profit, 2-year                      3072
#      Private for-profit, 4-year or above              632
#      Private for-profit, less-than 2-year            1327
#      Private not-for-profit, 2-year                   665
#      Private not-for-profit, 4-year or above         1059
#      Public, 2-year                                  1170
#      Public, 4-year or above                        12408
# 2013 Private for-profit, 2-year                      3053
#      Private for-profit, 4-year or above              775
#      Private for-profit, less-than 2-year            1281
#      Private not-for-profit, 2-year                   471
#      Private not-for-profit, 4-year or above         1016
#      Public, 2-year                                  1633
#      Public, 4-year or above                        12817
# 2014 Private for-profit, 2-year                      2957
# ...

# %%
df.groupby('Year').describe().transpose()
# Out:
# Year                      2012         2013         2014         2015  \
# Completions count    38.000000    40.000000    42.000000    44.000000
#             mean    535.078947   526.150000   588.809524   597.250000
#             std    1036.433239  1040.474782  1150.355857  1183.371791
#             min      13.000000     0.000000     0.000000     0.000000
#             25%     114.250000    98.500000   104.500000    87.750000
#             50%     229.500000   189.000000   203.500000   191.000000
#             75%     420.500000   413.000000   371.750000   405.750000
#             max    5388.000000  5278.000000  5093.000000  5335.000000
#
# Year                      2016
# Completions count    43.000000
#             mean    609.860465
#             std    1235.952796
#             min       0.000000
#             25%      90.000000
#             50%     208.000000
#             75%     414.000000
#             max    5367.000000

# %% [markdown]
# Operations Pandas

# %%
df_one = pd.DataFrame({'k1':['A','A','B','B','C','C'],
                      'col1':[100,200,300,100, 400,200],
                      'col2':['NY','CA','WA','WA','AK','NV']})

# %%
df_one
# Out:
#   k1  col1 col2
# 0  A   100   NY
# 1  A   200   CA
# 2  B   300   WA
# 3  B   100   WA
# 4  C   400   AK
# 5  C   200   NV

# %%
df_one['col2'].unique()
# Out:
# array(['NY', 'CA', 'WA', 'AK', 'NV'], dtype=object)

# %%
df_one['k1'].nunique()
# Out:
# 3

# %%
df_one['col2'].value_counts()
# Out:
# col2
# WA    2
# NY    1
# CA    1
# AK    1
# NV    1
# Name: count, dtype: int64

# %%
df_one.drop_duplicates()
#
# Out:
#   k1  col1 col2
# 0  A   100   NY
# 1  A   200   CA
# 2  B   300   WA
# 3  B   100   WA
# 4  C   400   AK
# 5  C   200   NV

# %%
df_one['NEW'] = df_one['col1'] * 10

# %%
df_one
# Out:
#   k1  col1 col2   NEW
# 0  A   100   NY  1000
# 1  A   200   CA  2000
# 2  B   300   WA  3000
# 3  B   100   WA  1000
# 4  C   400   AK  4000
# 5  C   200   NV  2000

# %%
def grab(state):
    return state[0]

# %%
grab('NY')
# Out:
# 'N'

# %%
df_one['col2'].apply(grab)
# Out:
# 0    N
# 1    C
# 2    W
# 3    W
# 4    A
# 5    N
# Name: col2, dtype: object

# %%
df_one['first_letter'] = df_one['col2'].apply(grab)

# %%
df_one
# Out:
#   k1  col1 col2   NEW first_letter
# 0  A   100   NY  1000            N
# 1  A   200   CA  2000            C
# 2  B   300   WA  3000            W
# 3  B   100   WA  1000            W
# 4  C   400   AK  4000            A
# 5  C   200   NV  2000            N

# %%
def complex_letter(state):
    if state[0] == 'W':
        return "Washington"
    else:
        return 'Error'

# %%
df_one['col2'].apply(complex_letter)
# Out:
# 0         Error
# 1         Error
# 2    Washington
# 3    Washington
# 4         Error
# 5         Error
# Name: col2, dtype: object

# %%
my_dic = {'A':1,'B':2,'C':3}

# %%
df_one['num'] = df_one['k1'].map(my_dic)

# %%
df_one
# Out:
#   k1  col1 col2   NEW first_letter  K1  num
# 0  A   100   NY  1000            N   1    1
# 1  A   200   CA  2000            C   1    1
# 2  B   300   WA  3000            W   2    2
# 3  B   100   WA  1000            W   2    2
# 4  C   400   AK  4000            A   3    3
# 5  C   200   NV  2000            N   3    3

# %%
df_one['col1'].idxmax()
# Out:
# 4

# %%
df_one['col1'].idxmin()
# Out:
# 0

# %%
df_one.columns = ['C1','C2','C3','C4','C5', 'C6', 'C7'] # Renommer les colonnes

# %%
df_one
# Out:
#   C1   C2  C3    C4 C5  C6  C7
# 0  A  100  NY  1000  N   1   1
# 1  A  200  CA  2000  C   1   1
# 2  B  300  WA  3000  W   2   2
# 3  B  100  WA  1000  W   2   2
# 4  C  400  AK  4000  A   3   3
# 5  C  200  NV  2000  N   3   3

# %%
df_one.sort_values('C3')
# Out:
#   C1   C2  C3    C4 C5  C6  C7
# 4  C  400  AK  4000  A   3   3
# 1  A  200  CA  2000  C   1   1
# 5  C  200  NV  2000  N   3   3
# 0  A  100  NY  1000  N   1   1
# 2  B  300  WA  3000  W   2   2
# 3  B  100  WA  1000  W   2   2

# %%
features = pd.DataFrame({'A':[100,200,300,400,500],
                        'B':[12,13,14,14,66]})
predictions = pd.DataFrame({'pred':[0,1,1,0,1]})

# %%
features
# Out:
#      A   B
# 0  100  12
# 1  200  13
# 2  300  14
# 3  400  14
# 4  500  66

# %%
predictions
# Out:
#    pred
# 0     0
# 1     1
# 2     1
# 3     0
# 4     1

# %%
pd.concat([features, predictions], axis=1)
# Out:
#      A   B  pred
# 0  100  12     0
# 1  200  13     1
# 2  300  14     1
# 3  400  14     0
# 4  500  66     1

# %%
df_one
# Out:
#   C1   C2  C3    C4 C5  C6  C7
# 0  A  100  NY  1000  N   1   1
# 1  A  200  CA  2000  C   1   1
# 2  B  300  WA  3000  W   2   2
# 3  B  100  WA  1000  W   2   2
# 4  C  400  AK  4000  A   3   3
# 5  C  200  NV  2000  N   3   3

# %%
df_one['C1']
# Out:
# 0    A
# 1    A
# 2    B
# 3    B
# 4    C
# 5    C
# Name: C1, dtype: object

# %%
pd.get_dummies(df_one['C1'])
# Out:
#        A      B      C
# 0   True  False  False
# 1   True  False  False
# 2  False   True  False
# 3  False   True  False
# 4  False  False   True
# 5  False  False   True

# %% [markdown]
# Data input et output

# %%
ls
# Out:
# drive/  sample_data/  Universities.csv

# %%
df = pd.read_csv('/content/drive/MyDrive/Deep_Learning_TF_2_Notebooks_et_Datasets/DATA/example.csv')

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df.to_csv('/content/new_file.csv', index=False)

# %%
pd.read_csv('/content/new_file.csv')
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
tables = pd.read_html('https://fr.wikipedia.org/wiki/Population_mondiale')

# %%
tables
# Out:
# [                                Région          2023 (%)        2030 (%)  \
#  0                Afrique subsaharienne  1 196,7 (14,9 %)  1 414 (16,6 %)
#  1  Afrique du Nord et Asie occidentale       568 (7,1 %)     631 (7,4 %)
#  2         Asie centrale et Asie du Sud  2 112,8 (26,2 %)  2 268 (26,6 %)
#  3     Asie de l'Est et Asie du Sud-Est  2 349,6 (29,2 %)  2 353 (27,6 %)
#  4           Europe et Amérique du Nord  1 127,5 (14,0 %)  1 136 (13,3 %)
#  5          Amérique latine et Caraïbes     656,6 (8,1 %)     686 (8,0 %)
#  6        Australie et Nouvelle-Zélande      31,5 (0,4 %)      33 (0,4 %)
#  7                Autres pays d'Océanie      13,8 (0,2 %)      15 (0,2 %)
#  8                                Monde           8 056,5           8 536
#
#           2050 (%)        2084 (%)        2100 (%)
#  0  2 077 (21,5 %)  3 060 (29,7 %)  3 345 (32,8 %)
#  1     789 (8,2 %)     956 (9,3 %)     987 (9,7 %)
#  2  2 613 (27,1 %)  2 742 (26,6 %)  2 643 (25,9 %)
# ...

# %%
tables[0]
# Out:
#                                 Région          2023 (%)        2030 (%)  \
# 0                Afrique subsaharienne  1 196,7 (14,9 %)  1 414 (16,6 %)
# 1  Afrique du Nord et Asie occidentale       568 (7,1 %)     631 (7,4 %)
# 2         Asie centrale et Asie du Sud  2 112,8 (26,2 %)  2 268 (26,6 %)
# 3     Asie de l'Est et Asie du Sud-Est  2 349,6 (29,2 %)  2 353 (27,6 %)
# 4           Europe et Amérique du Nord  1 127,5 (14,0 %)  1 136 (13,3 %)
# 5          Amérique latine et Caraïbes     656,6 (8,1 %)     686 (8,0 %)
# 6        Australie et Nouvelle-Zélande      31,5 (0,4 %)      33 (0,4 %)
# 7                Autres pays d'Océanie      13,8 (0,2 %)      15 (0,2 %)
# 8                                Monde           8 056,5           8 536
#
#          2050 (%)        2084 (%)        2100 (%)
# 0  2 077 (21,5 %)  3 060 (29,7 %)  3 345 (32,8 %)
# 1     789 (8,2 %)     956 (9,3 %)     987 (9,7 %)
# 2  2 613 (27,1 %)  2 742 (26,6 %)  2 643 (25,9 %)
# ...

# %%
type(tables)
# Out:
# list
